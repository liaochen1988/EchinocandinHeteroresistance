# %%
import sys
import os
import pandas as pd
import numpy as np
import itertools
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from copy import deepcopy
import joblib
from statannot import add_stat_annotation
import xgboost as xgb
import time
from matplotlib.ticker import MultipleLocator
from tqdm import tqdm
from statannot import add_stat_annotation
from joblib import Parallel, delayed
from statsmodels.stats.multitest import multipletests
import statsmodels.api as sm
import graphviz
import random

# sklearn
from sklearn.impute import SimpleImputer
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score, train_test_split, PredefinedSplit, StratifiedKFold
from sklearn.feature_selection import SelectKBest, f_classif, VarianceThreshold, SelectFromModel, SequentialFeatureSelector
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from sklearn.compose import ColumnTransformer, make_column_transformer
from  sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, IsolationForest
from sklearn.linear_model import Lasso, LassoCV, RidgeCV, LogisticRegression
from sklearn.preprocessing import FunctionTransformer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
import openTSNE
from sklearn.svm import SVC
from sklearn import tree
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score, precision_recall_curve, PrecisionRecallDisplay
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import statsmodels.api as sm

# imbalance learn
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN

# deepnet 
sys.path.insert(0, 'ENNS')
from dnp2 import DeepNet

import dataframe_image as dfi

from sklearn import set_config
set_config(transform_output="pandas")

import warnings
warnings.filterwarnings("ignore")
os.environ["PYTHONWARNINGS"] = "ignore::UserWarning"
np.seterr(divide='ignore', invalid='ignore')

import warnings
warnings.filterwarnings('ignore')

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
import matplotlib as matp
matp.__version__
# Out:
# '3.7.1'

# %%
import scipy as sci
sci.__version__
# Out:
# '1.10.1'

# %%
xgb.__version__
# Out:
# '1.7.6'

# %% [markdown]
# # Read features and HR phenotypes

# %%
df_X = pd.read_csv('../merge_features/pattern_all_isolates.csv', index_col=0)
df_y = pd.read_csv("../files_from_yy/hr_cla.csv", index_col=0)[['HR']].astype(int).loc[df_X.index]

# %%
df_X.shape, df_y.shape
# Out:
# ((219, 6806), (219, 1))

# %% [markdown]
# # Remove redundant isoaltes: pick one isolate among all identical ones within each patient

# %%
df_cluster = pd.read_csv("../ani_analysis/strain_clusters_popANI_99_999.csv", index_col=0)
df_cluster = df_cluster.loc[df_X.index]
df_cluster.head()
# Out:
#          ClusterName Institute Location     HR    Weight PatientID
# Isolate
# CDC335            17       CDC      USA  False  0.005495       NaN
# CDC336            12       CDC      USA  False  0.005495       NaN
# CDC337            12       CDC      USA  False  0.005495       NaN
# CDC338            35       CDC      USA  False  0.010989       NaN
# CDC339            29       CDC      USA  False  0.003663       NaN

# %%
print("%d out of %d isolates have patient information."%(len(df_cluster[df_cluster.PatientID.notnull()]), len(df_cluster)))
# Out:
# 104 out of 219 isolates have patient information.

# %%
Counter(df_cluster.Location)
# Out:
# Counter({'USA': 136, 'China': 73, 'Europe': 10})

# %%
Counter(df_cluster.HR)
# Out:
# Counter({False: 133, True: 86})

# %%
df_ani = pd.read_csv("../ani_analysis/popANI_wide_format.csv", index_col=0)
df_ani = df_ani.loc[df_X.index, df_X.index]
df_ani.head()
# Out:
# Isolate    CDC335    CDC336    CDC337    CDC338    CDC339    CDC340    CDC342  \
# Isolate
# CDC335   1.000000  0.999982  0.999982  0.999767  0.999758  0.999833  0.999820
# CDC336   0.999982  1.000000  1.000000  0.999769  0.999761  0.999835  0.999823
# CDC337   0.999982  1.000000  1.000000  0.999768  0.999760  0.999835  0.999822
# CDC338   0.999767  0.999769  0.999768  1.000000  0.999759  0.999770  0.999758
# CDC339   0.999758  0.999761  0.999760  0.999759  1.000000  0.999767  0.999758
#
# Isolate    CDC343    CDC344        E1  ...    MSK925   UWM1195   UWM1196  \
# Isolate                                ...
# CDC335   0.999757  0.999882  0.999746  ...  0.999942  0.999829  0.999829
# CDC336   0.999760  0.999885  0.999749  ...  0.999943  0.999831  0.999831
# CDC337   0.999760  0.999885  0.999749  ...  0.999943  0.999831  0.999831
# CDC338   0.999759  0.999768  0.999748  ...  0.999765  0.999766  0.999766
# CDC339   0.999985  0.999764  0.999874  ...  0.999757  0.999763  0.999764
#
# ...

# %%
selected_isolates = []
for pid in set(df_cluster[df_cluster.PatientID.notnull()].PatientID):
    df_pid = df_cluster[df_cluster.PatientID==pid]
    for cluster in set(df_pid.ClusterName):
        df_pid_cluster = df_pid[df_pid.ClusterName==cluster]

        # identify the mean distance between this selected isolate and every other isolates
        df_mean_ani = df_ani.mean(axis=1)[list(df_pid_cluster.index)]

        # select the isolate with longest distance
        isolate_most_dissimilar = df_mean_ani.sort_values().index[0]

        # output information
        print('Patient ID: %s, Cluster: %s'%(str(pid), str(cluster)))
        print('This patient and cluster combination has %d isolates, %d HR and %d S'%(
            len(df_pid_cluster),
            len(df_pid_cluster[(df_pid_cluster.PatientID==pid) & (df_pid_cluster.HR==True)]),
            len(df_pid_cluster[(df_pid_cluster.PatientID==pid) & (df_pid_cluster.HR==False)])
        ))
        print(isolate_most_dissimilar, '(HR=%d) was selected'%(df_pid_cluster.loc[isolate_most_dissimilar,'HR']))
        print()

        selected_isolates.append(isolate_most_dissimilar)
    
df_X = df_X.loc[list(df_cluster[df_cluster.PatientID.isnull()].index)+selected_isolates]
df_y = df_y.loc[df_X.index]
# Out:
# Patient ID: MSK_Pt_14, Cluster: 0
# This patient and cluster combination has 6 isolates, 6 HR and 0 S
# MSK624 (HR=1) was selected
#
# Patient ID: MSK_Pt_14, Cluster: 14
# This patient and cluster combination has 2 isolates, 0 HR and 2 S
# MSK620 (HR=0) was selected
#
# Patient ID: MSK_Pt_13, Cluster: 73
# This patient and cluster combination has 1 isolates, 0 HR and 1 S
# MSK2422 (HR=0) was selected
#
# Patient ID: MSK_Pt_13, Cluster: 31
# This patient and cluster combination has 1 isolates, 0 HR and 1 S
# MSK2415 (HR=0) was selected
#
# Patient ID: MSK_Pt_4, Cluster: 32
# This patient and cluster combination has 2 isolates, 0 HR and 2 S
# MSK1298 (HR=0) was selected
#
# Patient ID: MSK_Pt_20, Cluster: 26
# This patient and cluster combination has 2 isolates, 0 HR and 2 S
# MSK2425 (HR=0) was selected
#
# Patient ID: MSK_Pt_11, Cluster: 0
# This patient and cluster combination has 2 isolates, 2 HR and 0 S
# MSK1015 (HR=1) was selected
#
# Patient ID: MSK_Pt_11, Cluster: 69
# ...

# %%
Counter(df_cluster.loc[df_X.index].HR)
# Out:
# Counter({False: 109, True: 51})

# %%
len(df_X), len(df_y)
# Out:
# (160, 160)

# %% [markdown]
# # Random split samples into 80:20 ratio and run N times

# %%
# generate training and test dataset for N times
N = 20
random_state = 42
train_test_split_N_times = []
for local_index in np.arange(0,N):    
    # shuffle rows
    df_X_shuffle = deepcopy(df_X.sample(frac=1))
    df_y_shuffle = df_y.loc[df_X_shuffle.index]
    
    # get train and test dataset
    X_train, X_test, y_train, y_test = train_test_split(df_X_shuffle, df_y_shuffle, test_size=0.20, random_state=random_state, stratify=df_y_shuffle.HR)
    num_test_isolates = len(y_test)
    num_test_hr_isolates = len(y_test[y_test.HR==1])
    train_isolates = (',').join(list(X_train.index))
    test_isolates = (',').join(list(X_test.index))
    
    train_test_split_N_times.append([train_isolates, test_isolates, num_test_isolates, num_test_hr_isolates])
df_train_test_split_N_times = pd.DataFrame(train_test_split_N_times, columns=['Train','Test','Ntotal','Nhr'])
df_train_test_split_N_times.to_csv("train_test_split_%d_times.csv"%(N), index=False)
df_train_test_split_N_times.head()
# Out:
#                                                Train  \
# 0  CDC340,E7,E31,E69,E24,CDC339,E36,MSK2234,E10,E...
# 1  UWM1197,MSK810,E42,E71,E56,MSK809,MSK799,E6,E2...
# 2  E71,MSK810,MSK815,MSK2386,MSK1090,E81,E67,MSK1...
# 3  E35,MSK2191,UWM1198,E11,CDC342,E72,MSK810,E80,...
# 4  MSK2124,CDC344,E12,MSK250,UWM1204,E20,MSK802,C...
#
#                                                 Test  Ntotal  Nhr
# 0  E54,E44,UWM1204,UWM1197,CDC335,UWM1196,MSK2191...      32   10
# 1  GL23,E63,E39,E41,MSK620,UWM1208,E30,MSK807,MSK...      32   10
# 2  E36,E33,MSK844,MSK804,E56,UWM1208,GL105,GL29,M...      32   10
# 3  MSK808,MSK813,E60,E56,E40,MSK2124,MSK802,MSK79...      32   10
# 4  FM14,E14,E27,E66,E48,UWM1208,MSK1119,CDC343,GL...      32   10

# %%
grid_search_objects = {}
performance = []
global_index=0
for local_index in np.arange(0,N):
    print("running random split %d"%(local_index))
    
    # get train and test dataset
    train_isolates = df_train_test_split_N_times.loc[local_index,'Train'].split(',')
    test_isolates = df_train_test_split_N_times.loc[local_index,'Test'].split(',')
    X_train = deepcopy(df_X.loc[train_isolates])
    X_test = deepcopy(df_X.loc[test_isolates])
    y_train = deepcopy(df_y.loc[train_isolates])
    y_test = deepcopy(df_y.loc[test_isolates])
    
    ##################################
    # create pipeline
    ##################################
    scaler = StandardScaler().set_output(transform="pandas")
    thresholder = VarianceThreshold().set_output(transform="pandas")

    #####################################################
    # we consider the following feature selection methods
    #####################################################
    # logistic regression
    class feature_selector_logit(BaseEstimator, TransformerMixin):
        def __init__(self, n_features=10):
            self.n_features = n_features
            self.selected_features = None
        def fit(self, X, y=None):
            tmp = []
            for f in X.columns:
                xk = X[[f]]
                yk = y[['HR']]
                logit_model=sm.Logit(yk, sm.add_constant(xk))
                resk=logit_model.fit(method='bfgs', disp=0)
                tmp.append([f, resk.summary2().tables[1].loc[f,'P>|z|']])
            df_tmp = pd.DataFrame(tmp, columns=['Feature','Pvalue'])
            df_tmp = df_tmp[df_tmp.Pvalue.notnull()]
            df_tmp = df_tmp.sort_values('Pvalue')
            self.selected_features = list(df_tmp.iloc[:self.n_features].Feature)
            return self
        def transform(self, X, y=None, **kwargs):
            return X[self.selected_features]

    # anova F
    class feature_selector_anovaF(BaseEstimator, TransformerMixin):
        def __init__(self, n_features=10):
            self.n_features = n_features
            self.selected_features = None
        def fit(self, X, y=None):
            X_new = SelectKBest(score_func=f_classif, k=self.n_features).fit_transform(X, y)
            self.selected_features = list(X_new.columns)
            return self
        def transform(self, X, y=None, **kwargs):
            return X[self.selected_features]

    # Lasso
    class feature_selector_lasso(BaseEstimator, TransformerMixin):
        def __init__(self, n_features=10):
            self.n_features = n_features
            self.selected_features = None
        def fit(self, X, y=None):
            reg = LassoCV(
                cv=3,
                random_state=42,
                n_alphas=1000,
                max_iter=100000,
                verbose=0,
                n_jobs=-1
            ).fit(X.values, np.ravel(y.values))
            df_reg = pd.DataFrame(reg.coef_, index=X.columns, columns=['Coef'])
            df_reg = df_reg[df_reg.Coef != 0]
            df_reg['AbsCoef'] = np.abs(df_reg['Coef'])
            df_reg = df_reg.sort_values('AbsCoef', ascending=False)
            
            # deal with situation when no feature was selected
            if len(df_reg) == 0:
                # then randomly selected n_features
                self.selected_features = random.sample(X.columns, self.n_features)
            else:
                if len(df_reg) > self.n_features:
                    df_reg = df_reg.iloc[:self.n_features,:]
                    assert len(df_reg) == self.n_features
                self.selected_features = list(df_reg.index)
            return self
        def transform(self, X, y=None, **kwargs):
            return X[self.selected_features]
        
    # deepNet
    class feature_selector_dnp(BaseEstimator, TransformerMixin):
        def __init__(self, n_features=10):
            self.n_features = n_features
            self.selected_features = None
        def fit(self, X, y=None):
            slc = DeepNet(max_feature=self.n_features)
            self.selected_features = [list(X.columns)[idx-1] for idx in slc.train(X, y, return_select=True, verbosity=2)]
            return self
        def transform(self, X, y=None, **kwargs):
            return X[self.selected_features]
        
    feature_selectors = {
        'Logit':feature_selector_logit(),
        'Ftest':feature_selector_anovaF(),
        'Lasso':feature_selector_lasso(),
        'DNP':feature_selector_dnp()
    }

    # classifier
    decision_tree = DecisionTreeClassifier(random_state=random_state, class_weight="balanced")
    random_forest = RandomForestClassifier(n_estimators=1000, random_state=random_state, class_weight="balanced")
    xgboost = xgb.XGBClassifier(n_estimators=1000, seed=random_state, objective='binary:logistic')
    
    classifiers = {
        'DT':decision_tree,
        'RFC':random_forest,
        'XGB':xgboost
    }

    ##########################################
    # evaluate performance on test set
    ##########################################
    for FsMethod in ['Logit','Lasso','DNP']:
        for ClaModel in ['DT','RFC','XGB']:
            if ClaModel=='RFC':
                parameters = {
                    'feature_selector__n_features':[2,4,6,8,10],
                    'classifier__max_features':['sqrt',None],
                    'classifier__max_depth':[2,4,6],
                    'classifier__max_samples':[0.5,0.75,1.0]
                }
            elif ClaModel=='DT':
                parameters = {
                    'feature_selector__n_features':[2,4,6,8,10],
                    'classifier__max_features':['sqrt',None],
                    'classifier__max_depth':[2,4,6]
                }
            elif ClaModel=='XGB':
                parameters = {
                    'feature_selector__n_features':[2,4,6,8,10],
                    'classifier__colsample_bytree':[0.5,0.75,1.0],
                    'classifier__max_depth':[2,4,6],
                    'classifier__learning_rate':[0.3,0.1,0.03]
                }

            # create pipeline
            pipeline = Pipeline(
                steps=[
                    ("scaler", scaler), 
                    ("thresholder", thresholder),
                    ("feature_selector", feature_selectors[FsMethod]), 
                    ("classifier", classifiers[ClaModel])
                ]
            )

            # run grid search
            CV = GridSearchCV(pipeline, parameters, scoring='f1', cv=StratifiedKFold(n_splits=5), n_jobs=-1, verbose=0)
            CV.fit(X_train,y_train)
        
            # compute training scores
            final_model = CV.best_estimator_
            y_pred = CV.predict(X_train)
            accuracy_train = accuracy_score(y_true=y_train, y_pred=y_pred)
            precision_train = precision_score(y_true=y_train, y_pred=y_pred)
            recall_train = recall_score(y_true=y_train, y_pred=y_pred)
            f1_train = f1_score(y_true=y_train, y_pred=y_pred)
            FN_train = []
            FP_train = []
            for ti,y1,y2 in zip(list(X_train.index),list(y_pred),list(y_train.HR)):
                if y1 == 0 and y2 == 1:
                    FN_train.append(ti)
                if y1 == 1 and y2 == 0:
                    FP_train.append(ti)

            # compute test scores
            y_pred = CV.predict(X_test)
            accuracy_test = accuracy_score(y_true=y_test, y_pred=y_pred)
            precision_test = precision_score(y_true=y_test, y_pred=y_pred)
            recall_test = recall_score(y_true=y_test, y_pred=y_pred)
            f1_test = f1_score(y_true=y_test, y_pred=y_pred)
            FN_test = []
            FP_test = []
            for ti,y1,y2 in zip(list(X_test.index),list(y_pred),list(y_test.HR)):
                if y1 == 0 and y2 == 1:
                    FN_test.append(ti)
                if y1 == 1 and y2 == 0:
                    FP_test.append(ti)
            
            # get number of features
            X_train2 = scaler.fit_transform(X_train)
            X_train2 = thresholder.fit_transform(X_train2)
            n_features = CV.best_params_['feature_selector__n_features']
            selected_features = CV.best_estimator_.steps[-2][1].selected_features
            feature_importance = list(CV.best_estimator_.steps[-1][1].feature_importances_)
            selected_features = ["%s (%2.4f)"%(x,y) for y, x in sorted(zip(feature_importance, selected_features), reverse=True)] 

            # get best parameters
            bestp = ''
            for k,v in CV.best_params_.items():
                bestp += '%s:%s,'%(k,v)
            bestp = bestp.rstrip(',')
                
            # save to results
            performance.append([local_index, global_index, FsMethod, ClaModel, n_features, (',').join(selected_features), bestp,
                                accuracy_train, precision_train, recall_train, f1_train, (',').join(FN_train), (',').join(FP_train),
                                accuracy_test, precision_test, recall_test, f1_test, (',').join(FN_test), (',').join(FP_test)])
            grid_search_objects[global_index] = deepcopy(CV)
            global_index += 1
            
df_performance = pd.DataFrame(performance, 
                              columns=[
                                  'local_index','global_index','feature_selection_method','classification_model','best_model_n_features','selected_features','best_params',
                                  'accuracy_train','precision_train','recall_train','f1_train','false_negative_train','false_positive_train',
                                  'accuracy_test','precision_test','recall_test','f1_test','false_negative_test','false_positive_test'
                              ]
                             )
df_performance.to_csv("method_assessment_random_split_%d_times.all_features.csv"%(N), index=False)
df_performance.head()
# Out:
# running random split 0
# running random split 1
# /usr/local/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:1819: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /usr/local/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:1819: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /usr/local/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:1819: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /usr/local/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:1819: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /usr/local/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:1819: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /usr/local/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:1819: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# ...

# %% [markdown]
# # Compare the performance of different methods

# %%
df2plot = df_performance[['local_index','feature_selection_method','classification_model','precision_test','recall_test','f1_test','accuracy_test']]
df2plot['method'] = [x+'+'+y for x,y in zip(df2plot.feature_selection_method, df2plot.classification_model)]

PROPS = {
    'boxprops':{'facecolor':'none', 'edgecolor':'black'},
    'medianprops':{'color':'black'},
    'whiskerprops':{'color':'black'},
    'capprops':{'color':'black'}
}

fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(15,4), sharey=True)

for k, metric in enumerate(['precision_test','recall_test','f1_test','accuracy_test']):
    order = list(df2plot.groupby('method')[metric].agg(np.median).sort_values().index)
    _ = sns.boxplot(x="method", y=metric, data=df2plot, showfliers=False, **PROPS, order=order, ax=ax[k])
    _ = sns.stripplot(x="method", y=metric, data=df2plot, order=order, ax=ax[k], palette='Set1')
#    _ = ax[k].set_ylim([0.6,1])
    _ = ax[k].set_xticklabels(ax[k].get_xticklabels(), rotation=90)
    _ = ax[k].set_xlabel('')
    _ = ax[k].set_ylabel(metric.replace("_test",""), fontsize=12)
    
    # if metric=='f1_test':
    #     test_results = add_stat_annotation(
    #         ax[k], data=df2plot, x="method", y=metric, order=order,
    #         box_pairs=[(order[0], order[-1]), (order[1], order[-1]), (order[2], order[-1]),
    #                    (order[3], order[-1]), (order[4], order[-1]), (order[5], order[-1]),
    #                    (order[6], order[-1]), (order[7], order[-1])
    #                   ],
    #         test='Wilcoxon', text_format='full', loc='outside', verbose=2, comparisons_correction='bonferroni')
        
    print(metric, 'best approach', order[-1])
    print('median performance', df2plot.loc[df2plot.method==order[-1],metric].median())
    print('\n')    
        
plt.tight_layout()
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig("boxplot_performance_split_%d_times.all_features.png"%(N), dpi=600)
fig.savefig("boxplot_performance_split_%d_times.all_features.svg"%(N), dpi=600)
# Out:
# precision_test best approach Logit+XGB
# median performance 0.7777777777777778
#
#
# recall_test best approach Logit+XGB
# median performance 0.7
#
#
# f1_test best approach Logit+XGB
# median performance 0.7320574162679425
#
#
# accuracy_test best approach Logit+XGB
# median performance 0.828125
